# %%
# %time
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load the dataset
df = pd.read_csv('/home/muzaffar/Desktop/Farhat/paper-000/delta-mfcc/delta-mfcc.csv')  # Change the path accordingly

# Assuming 'word_label' is the last column
label_column = 'word_label'

# Check if the label column is present
if label_column not in df.columns:
    raise KeyError(f"The '{label_column}' column is not present in the DataFrame.")

# Extract features and labels
X = df.iloc[:, :-1].values  # All columns except the last one
y = df[label_column].values

# Encode the labels
le = LabelEncoder()
y = le.fit_transform(y)

# Standardize the input features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Perform 10-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

fold_accuracies = []
all_histories = []

# Number of time steps should be a divisor of the number of features
n_time_steps = 3  # Adjust this value to be a divisor of 39
n_features_per_timestep = X.shape[1] // n_time_steps

# Lists to store true and predicted labels across all folds
all_true_labels = []
all_predicted_labels = []

for fold, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Training Fold {fold + 1}...")

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Reshape the input data for LSTM
    X_train = np.reshape(X_train, (X_train.shape[0], n_time_steps, n_features_per_timestep))
    X_test = np.reshape(X_test, (X_test.shape[0], n_time_steps, n_features_per_timestep))

    # Create the LSTM model with additional Bidirectional and Dropout layers
    model = Sequential()
    model.add(Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(n_time_steps, n_features_per_timestep)))
    model.add(BatchNormalization())
    model.add(Bidirectional(LSTM(128, activation='relu', return_sequences=True)))
    model.add(BatchNormalization())
    model.add(Bidirectional(LSTM(64, activation='relu')))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(len(np.unique(y)), activation='softmax'))

    optimizer = SGD(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Create ModelCheckpoint callback to save the best weights
    checkpoint_path = f'model_checkpoint_fold_{fold + 1}.keras'

    model_checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')

    # Train the model and save the training history
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    history = model.fit(
        X_train, y_train, epochs=30, batch_size=64,
        verbose=1, validation_data=(X_test, y_test),
        callbacks=[early_stopping, model_checkpoint]
    )

    # Save the training history
    with open(f'training_history_fold_{fold + 1}.pkl', 'wb') as f:
        pickle.dump(history.history, f)

    all_histories.append(history.history)

    # Make predictions on the test set
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Store true and predicted labels
    all_true_labels.extend(y_test)
    all_predicted_labels.extend(y_pred)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    fold_accuracies.append(accuracy)
    print(f'Fold {fold + 1} - Accuracy: {accuracy}')

# Calculate and print the average accuracy across all folds
average_accuracy = np.mean(fold_accuracies)
print(f'Average Accuracy Across Folds: {average_accuracy}')

# Generate confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)
# print("Confusion Matrix:")
# print(conf_matrix)

# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels)
# print("Classification Report:")
# print(class_report)

# Plot accuracy across folds
def plot_learning_behavior(histories, metric='accuracy'):
    plt.figure(figsize=(12, 8))

    for i, history in enumerate(histories):
        plt.plot(history[metric], label=f'Fold {i + 1}')

    plt.title(f'Model {metric.capitalize()} Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.show()

# Plot accuracy across folds
plot_learning_behavior(all_histories, metric='accuracy')

# Plot loss across folds
plot_learning_behavior(all_histories, metric='loss')
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 3.34 µs
# 2024-07-11 10:51:10.945556: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-11 10:51:11.566598: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Training Fold 1...
# 2024-07-11 10:51:15.580781: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.618251: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.618407: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.619396: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.619519: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.619627: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.670009: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.670216: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.670392: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-11 10:51:15.670516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10230 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# /home/muzaffar/anaconda3/envs/tf12/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720675280.125011   21912 service.cc:145] XLA service 0xfe3cb60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1720675280.125032   21912 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2024-07-11 10:51:20.236962: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-11 10:51:20.648982: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
#   48/6628 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.0987 - loss: 2.9946
# I0000 00:00:1720675283.221327   21912 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.1355 - loss: 2.6005 - val_accuracy: 0.2524 - val_loss: 2.0578
# Epoch 2/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2186 - loss: 2.1696 - val_accuracy: 0.3004 - val_loss: 1.9336
# Epoch 3/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.2600 - loss: 2.0337 - val_accuracy: 0.3251 - val_loss: 1.8597
# Epoch 4/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2851 - loss: 1.9563 - val_accuracy: 0.3438 - val_loss: 1.8082
# Epoch 5/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.3064 - loss: 1.8964 - val_accuracy: 0.3577 - val_loss: 1.7709
# Epoch 6/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3233 - loss: 1.8519 - val_accuracy: 0.3723 - val_loss: 1.7350
# Epoch 7/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3374 - loss: 1.8166 - val_accuracy: 0.3825 - val_loss: 1.7050
# Epoch 8/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3478 - loss: 1.7884 - val_accuracy: 0.3936 - val_loss: 1.6784
# Epoch 9/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.3591 - loss: 1.7611 - val_accuracy: 0.4036 - val_loss: 1.6530
# Epoch 10/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.3682 - loss: 1.7366 - val_accuracy: 0.4128 - val_loss: 1.6314
# Epoch 11/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3775 - loss: 1.7126 - val_accuracy: 0.4206 - val_loss: 1.6098
# Epoch 12/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3862 - loss: 1.6911 - val_accuracy: 0.4286 - val_loss: 1.5905
# Epoch 13/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.3937 - loss: 1.6731 - val_accuracy: 0.4349 - val_loss: 1.5714
# Epoch 14/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4018 - loss: 1.6507 - val_accuracy: 0.4420 - val_loss: 1.5545
# Epoch 15/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4090 - loss: 1.6334 - val_accuracy: 0.4483 - val_loss: 1.5371
# Epoch 16/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4165 - loss: 1.6168 - val_accuracy: 0.4542 - val_loss: 1.5217
# Epoch 17/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4225 - loss: 1.6003 - val_accuracy: 0.4601 - val_loss: 1.5096
# Epoch 18/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4285 - loss: 1.5854 - val_accuracy: 0.4666 - val_loss: 1.4932
# Epoch 19/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4347 - loss: 1.5679 - val_accuracy: 0.4740 - val_loss: 1.4778
# Epoch 20/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4405 - loss: 1.5555 - val_accuracy: 0.4765 - val_loss: 1.4652
# Epoch 21/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4472 - loss: 1.5387 - val_accuracy: 0.4813 - val_loss: 1.4527
# Epoch 22/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4527 - loss: 1.5226 - val_accuracy: 0.4872 - val_loss: 1.4368
# Epoch 23/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4575 - loss: 1.5111 - val_accuracy: 0.4899 - val_loss: 1.4261
# Epoch 24/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4620 - loss: 1.4984 - val_accuracy: 0.4969 - val_loss: 1.4141
# Epoch 25/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4671 - loss: 1.4884 - val_accuracy: 0.5004 - val_loss: 1.4041
# Epoch 26/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4735 - loss: 1.4704 - val_accuracy: 0.5045 - val_loss: 1.3923
# Epoch 27/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4776 - loss: 1.4582 - val_accuracy: 0.5086 - val_loss: 1.3802
# Epoch 28/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4810 - loss: 1.4491 - val_accuracy: 0.5137 - val_loss: 1.3702
# Epoch 29/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4860 - loss: 1.4362 - val_accuracy: 0.5153 - val_loss: 1.3600
# Epoch 30/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4906 - loss: 1.4245 - val_accuracy: 0.5218 - val_loss: 1.3495
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Fold 1 - Accuracy: 0.5218420506629949
# Training Fold 2...
# /home/muzaffar/anaconda3/envs/tf12/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.1311 - loss: 2.6151 - val_accuracy: 0.2507 - val_loss: 2.0669
# Epoch 2/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2147 - loss: 2.1764 - val_accuracy: 0.2998 - val_loss: 1.9374
# Epoch 3/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2561 - loss: 2.0368 - val_accuracy: 0.3265 - val_loss: 1.8634
# Epoch 4/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2846 - loss: 1.9560 - val_accuracy: 0.3447 - val_loss: 1.8125
# Epoch 5/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3049 - loss: 1.9007 - val_accuracy: 0.3582 - val_loss: 1.7727
# Epoch 6/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3206 - loss: 1.8583 - val_accuracy: 0.3690 - val_loss: 1.7396
# Epoch 7/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3333 - loss: 1.8221 - val_accuracy: 0.3797 - val_loss: 1.7101
# Epoch 8/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3456 - loss: 1.7931 - val_accuracy: 0.3892 - val_loss: 1.6834
# Epoch 9/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3574 - loss: 1.7642 - val_accuracy: 0.3991 - val_loss: 1.6583
# Epoch 10/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3655 - loss: 1.7410 - val_accuracy: 0.4097 - val_loss: 1.6348
# Epoch 11/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3740 - loss: 1.7185 - val_accuracy: 0.4170 - val_loss: 1.6144
# Epoch 12/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3838 - loss: 1.6941 - val_accuracy: 0.4269 - val_loss: 1.5949
# Epoch 13/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3912 - loss: 1.6753 - val_accuracy: 0.4320 - val_loss: 1.5758
# Epoch 14/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3995 - loss: 1.6550 - val_accuracy: 0.4404 - val_loss: 1.5592
# Epoch 15/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4075 - loss: 1.6344 - val_accuracy: 0.4481 - val_loss: 1.5421
# Epoch 16/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4137 - loss: 1.6208 - val_accuracy: 0.4543 - val_loss: 1.5259
# Epoch 17/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4224 - loss: 1.6005 - val_accuracy: 0.4591 - val_loss: 1.5116
# Epoch 18/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4278 - loss: 1.5868 - val_accuracy: 0.4644 - val_loss: 1.4963
# Epoch 19/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4348 - loss: 1.5677 - val_accuracy: 0.4706 - val_loss: 1.4809
# Epoch 20/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4391 - loss: 1.5565 - val_accuracy: 0.4762 - val_loss: 1.4670
# Epoch 21/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4457 - loss: 1.5397 - val_accuracy: 0.4800 - val_loss: 1.4553
# Epoch 22/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4519 - loss: 1.5246 - val_accuracy: 0.4862 - val_loss: 1.4396
# Epoch 23/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4547 - loss: 1.5131 - val_accuracy: 0.4881 - val_loss: 1.4297
# Epoch 24/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4625 - loss: 1.4968 - val_accuracy: 0.4949 - val_loss: 1.4147
# Epoch 25/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4676 - loss: 1.4828 - val_accuracy: 0.4988 - val_loss: 1.4055
# Epoch 26/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4700 - loss: 1.4745 - val_accuracy: 0.5022 - val_loss: 1.3952
# Epoch 27/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4780 - loss: 1.4581 - val_accuracy: 0.5049 - val_loss: 1.3847
# Epoch 28/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4807 - loss: 1.4477 - val_accuracy: 0.5053 - val_loss: 1.3779
# Epoch 29/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4859 - loss: 1.4366 - val_accuracy: 0.5120 - val_loss: 1.3642
# Epoch 30/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - accuracy: 0.4891 - loss: 1.4260 - val_accuracy: 0.5115 - val_loss: 1.3684
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Fold 2 - Accuracy: 0.5120009808267237
# Training Fold 3...
# /home/muzaffar/anaconda3/envs/tf12/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.1361 - loss: 2.6017 - val_accuracy: 0.2554 - val_loss: 2.0513
# Epoch 2/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2176 - loss: 2.1621 - val_accuracy: 0.3013 - val_loss: 1.9334
# Epoch 3/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2587 - loss: 2.0312 - val_accuracy: 0.3273 - val_loss: 1.8608
# Epoch 4/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2862 - loss: 1.9522 - val_accuracy: 0.3470 - val_loss: 1.8073
# Epoch 5/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3051 - loss: 1.8977 - val_accuracy: 0.3622 - val_loss: 1.7660
# Epoch 6/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3222 - loss: 1.8547 - val_accuracy: 0.3762 - val_loss: 1.7323
# Epoch 7/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3358 - loss: 1.8187 - val_accuracy: 0.3889 - val_loss: 1.6991
# Epoch 8/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3479 - loss: 1.7874 - val_accuracy: 0.3976 - val_loss: 1.6710
# Epoch 9/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3601 - loss: 1.7565 - val_accuracy: 0.4096 - val_loss: 1.6449
# Epoch 10/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3703 - loss: 1.7334 - val_accuracy: 0.4198 - val_loss: 1.6212
# Epoch 11/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3800 - loss: 1.7089 - val_accuracy: 0.4261 - val_loss: 1.5994
# Epoch 12/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.3882 - loss: 1.6876 - val_accuracy: 0.4335 - val_loss: 1.5783
# Epoch 13/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3981 - loss: 1.6665 - val_accuracy: 0.4415 - val_loss: 1.5597
# Epoch 14/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4028 - loss: 1.6458 - val_accuracy: 0.4473 - val_loss: 1.5404
# Epoch 15/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4115 - loss: 1.6284 - val_accuracy: 0.4545 - val_loss: 1.5236
# Epoch 16/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4175 - loss: 1.6111 - val_accuracy: 0.4609 - val_loss: 1.5063
# Epoch 17/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4254 - loss: 1.5928 - val_accuracy: 0.4660 - val_loss: 1.4900
# Epoch 18/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4328 - loss: 1.5730 - val_accuracy: 0.4733 - val_loss: 1.4750
# Epoch 19/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4397 - loss: 1.5551 - val_accuracy: 0.4775 - val_loss: 1.4610
# Epoch 20/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4455 - loss: 1.5425 - val_accuracy: 0.4825 - val_loss: 1.4472
# Epoch 21/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4493 - loss: 1.5288 - val_accuracy: 0.4843 - val_loss: 1.4420
# Epoch 22/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4561 - loss: 1.5115 - val_accuracy: 0.4909 - val_loss: 1.4235
# Epoch 23/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4620 - loss: 1.4974 - val_accuracy: 0.4968 - val_loss: 1.4094
# Epoch 24/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4682 - loss: 1.4841 - val_accuracy: 0.5011 - val_loss: 1.3976
# Epoch 25/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4729 - loss: 1.4713 - val_accuracy: 0.5057 - val_loss: 1.3855
# Epoch 26/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4774 - loss: 1.4594 - val_accuracy: 0.5080 - val_loss: 1.3803
# Epoch 27/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4815 - loss: 1.4472 - val_accuracy: 0.5125 - val_loss: 1.3640
# Epoch 28/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4853 - loss: 1.4374 - val_accuracy: 0.5179 - val_loss: 1.3527
# Epoch 29/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4894 - loss: 1.4272 - val_accuracy: 0.5198 - val_loss: 1.3450
# Epoch 30/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.4961 - loss: 1.4107 - val_accuracy: 0.5213 - val_loss: 1.3414
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Fold 3 - Accuracy: 0.521309403676214
# Training Fold 4...
# /home/muzaffar/anaconda3/envs/tf12/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.1355 - loss: 2.5911 - val_accuracy: 0.2504 - val_loss: 2.0662
# Epoch 2/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.2130 - loss: 2.1741 - val_accuracy: 0.2967 - val_loss: 1.9483
# Epoch 3/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.2536 - loss: 2.0438 - val_accuracy: 0.3231 - val_loss: 1.8771
# Epoch 4/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.2835 - loss: 1.9624 - val_accuracy: 0.3417 - val_loss: 1.8250
# Epoch 5/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3014 - loss: 1.9080 - val_accuracy: 0.3563 - val_loss: 1.7829
# Epoch 6/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3195 - loss: 1.8639 - val_accuracy: 0.3687 - val_loss: 1.7489
# Epoch 7/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3334 - loss: 1.8247 - val_accuracy: 0.3809 - val_loss: 1.7180
# Epoch 8/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3444 - loss: 1.7943 - val_accuracy: 0.3901 - val_loss: 1.6914
# Epoch 9/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3545 - loss: 1.7699 - val_accuracy: 0.4000 - val_loss: 1.6677
# Epoch 10/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3633 - loss: 1.7440 - val_accuracy: 0.4076 - val_loss: 1.6454
# Epoch 11/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3740 - loss: 1.7185 - val_accuracy: 0.4174 - val_loss: 1.6236
# Epoch 12/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3827 - loss: 1.6989 - val_accuracy: 0.4237 - val_loss: 1.6033
# Epoch 13/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.3902 - loss: 1.6785 - val_accuracy: 0.4305 - val_loss: 1.5857
# Epoch 14/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3979 - loss: 1.6593 - val_accuracy: 0.4388 - val_loss: 1.5665
# Epoch 15/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4056 - loss: 1.6420 - val_accuracy: 0.4459 - val_loss: 1.5478
# Epoch 16/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4138 - loss: 1.6215 - val_accuracy: 0.4514 - val_loss: 1.5304
# Epoch 17/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4212 - loss: 1.6046 - val_accuracy: 0.4576 - val_loss: 1.5160
# Epoch 18/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4279 - loss: 1.5867 - val_accuracy: 0.4642 - val_loss: 1.5011
# Epoch 19/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4329 - loss: 1.5726 - val_accuracy: 0.4702 - val_loss: 1.4866
# Epoch 20/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4383 - loss: 1.5579 - val_accuracy: 0.4767 - val_loss: 1.4727
# Epoch 21/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4465 - loss: 1.5409 - val_accuracy: 0.4803 - val_loss: 1.4605
# Epoch 22/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4515 - loss: 1.5287 - val_accuracy: 0.4850 - val_loss: 1.4460
# Epoch 23/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4558 - loss: 1.5164 - val_accuracy: 0.4904 - val_loss: 1.4326
# Epoch 24/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4627 - loss: 1.4984 - val_accuracy: 0.4947 - val_loss: 1.4212
# Epoch 25/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4663 - loss: 1.4866 - val_accuracy: 0.4975 - val_loss: 1.4139
# Epoch 26/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - accuracy: 0.4720 - loss: 1.4742 - val_accuracy: 0.5001 - val_loss: 1.4031
# Epoch 27/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4766 - loss: 1.4602 - val_accuracy: 0.5061 - val_loss: 1.3882
# Epoch 28/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4808 - loss: 1.4500 - val_accuracy: 0.5042 - val_loss: 1.3855
# Epoch 29/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4850 - loss: 1.4402 - val_accuracy: 0.5137 - val_loss: 1.3689
# Epoch 30/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4870 - loss: 1.4305 - val_accuracy: 0.5169 - val_loss: 1.3583
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Fold 4 - Accuracy: 0.5169145454716928
# Training Fold 5...
# /home/muzaffar/anaconda3/envs/tf12/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 35s 4ms/step - accuracy: 0.1352 - loss: 2.6130 - val_accuracy: 0.2522 - val_loss: 2.0601
# Epoch 2/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.2165 - loss: 2.1709 - val_accuracy: 0.2971 - val_loss: 1.9367
# Epoch 3/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.2594 - loss: 2.0334 - val_accuracy: 0.3238 - val_loss: 1.8632
# Epoch 4/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.2882 - loss: 1.9529 - val_accuracy: 0.3423 - val_loss: 1.8135
# Epoch 5/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3076 - loss: 1.8946 - val_accuracy: 0.3579 - val_loss: 1.7724
# Epoch 6/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3255 - loss: 1.8510 - val_accuracy: 0.3712 - val_loss: 1.7383
# Epoch 7/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3381 - loss: 1.8135 - val_accuracy: 0.3836 - val_loss: 1.7074
# Epoch 8/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3489 - loss: 1.7871 - val_accuracy: 0.3940 - val_loss: 1.6807
# Epoch 9/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3586 - loss: 1.7621 - val_accuracy: 0.4031 - val_loss: 1.6561
# Epoch 10/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3706 - loss: 1.7331 - val_accuracy: 0.4130 - val_loss: 1.6321
# Epoch 11/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3783 - loss: 1.7093 - val_accuracy: 0.4209 - val_loss: 1.6099
# Epoch 12/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3889 - loss: 1.6863 - val_accuracy: 0.4282 - val_loss: 1.5895
# Epoch 13/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.3970 - loss: 1.6649 - val_accuracy: 0.4362 - val_loss: 1.5709
# Epoch 14/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4050 - loss: 1.6465 - val_accuracy: 0.4430 - val_loss: 1.5517
# Epoch 15/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4117 - loss: 1.6284 - val_accuracy: 0.4489 - val_loss: 1.5365
# Epoch 16/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4176 - loss: 1.6091 - val_accuracy: 0.4537 - val_loss: 1.5179
# Epoch 17/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4257 - loss: 1.5931 - val_accuracy: 0.4608 - val_loss: 1.5043
# Epoch 18/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4326 - loss: 1.5750 - val_accuracy: 0.4673 - val_loss: 1.4881
# Epoch 19/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4373 - loss: 1.5616 - val_accuracy: 0.4720 - val_loss: 1.4754
# Epoch 20/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4437 - loss: 1.5464 - val_accuracy: 0.4779 - val_loss: 1.4598
# Epoch 21/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4500 - loss: 1.5285 - val_accuracy: 0.4819 - val_loss: 1.4474
# Epoch 22/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4561 - loss: 1.5123 - val_accuracy: 0.4867 - val_loss: 1.4347
# Epoch 23/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4624 - loss: 1.4999 - val_accuracy: 0.4932 - val_loss: 1.4198
# Epoch 24/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4656 - loss: 1.4898 - val_accuracy: 0.4954 - val_loss: 1.4090
# Epoch 25/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4707 - loss: 1.4742 - val_accuracy: 0.5018 - val_loss: 1.3987
# Epoch 26/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4740 - loss: 1.4651 - val_accuracy: 0.5012 - val_loss: 1.3957
# Epoch 27/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4805 - loss: 1.4505 - val_accuracy: 0.5091 - val_loss: 1.3770
# Epoch 28/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4850 - loss: 1.4413 - val_accuracy: 0.5107 - val_loss: 1.3711
# Epoch 29/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4903 - loss: 1.4258 - val_accuracy: 0.5145 - val_loss: 1.3613
# Epoch 30/30
# 6628/6628 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.4945 - loss: 1.4148 - val_accuracy: 0.5192 - val_loss: 1.3497
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Fold 5 - Accuracy: 0.519225146888233
# Average Accuracy Across Folds: 0.5182584255051716

# %%
# Plot accuracy across folds
def plot_learning_behavior(histories, metric='accuracy'):
    plt.figure(figsize=(4, 2))

    for i, history in enumerate(histories):
        plt.plot(history[metric], label=f'Fold {i + 1}')

    plt.title(f'Model {metric.capitalize()} Across Folds')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.show()

# Plot accuracy across folds
plot_learning_behavior(all_histories, metric='accuracy')

# Plot loss across folds
plot_learning_behavior(all_histories, metric='loss')

# %%
# Calculate and print the average accuracy across all folds
average_accuracy = np.mean(fold_accuracies)
print(f'Average Accuracy Across Folds: {average_accuracy}')
# Out:
# Average Accuracy Across Folds: 0.5182584255051716

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Generate confusion matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)

# Normalize the confusion matrix by row (true labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as heatmap with annotated percentages
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix_normalized, cmap='viridis', interpolation='nearest')

# Choose appropriate text color based on background color
threshold = conf_matrix_normalized.max() / 2.

for i in range(conf_matrix_normalized.shape[0]):
    for j in range(conf_matrix_normalized.shape[1]):
        color = "white" if conf_matrix_normalized[i, j] < threshold else "black"
        plt.text(j, i, format(conf_matrix_normalized[i, j], '.2f'), horizontalalignment="center", color=color)

# Custom ticks
custom_ticks = ['Akh', 'Zie', 'Thrre', 'Tsor', 'Pancs', "Shae", "Sath", "Eahght", "Nav","Daah"]
plt.xticks(np.arange(10), custom_ticks, rotation=45)
plt.yticks(np.arange(10), custom_ticks)

plt.colorbar()
plt.title('Confusion Matrix (Normalized)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Generate classification report
class_report = classification_report(all_true_labels, all_predicted_labels)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.53     45126
#            1       0.40      0.56      0.47     49488
#            2       0.51      0.52      0.52     54311
#            3       0.56      0.54      0.55     55820
#            4       0.61      0.51      0.55     55346
#            5       0.45      0.48      0.47     52672
#            6       0.63      0.53      0.57     55175
#            7       0.41      0.46      0.43     49694
#            8       0.57      0.48      0.52     56623
#            9       0.56      0.58      0.57     55911
#
#     accuracy                           0.52    530166
#    macro avg       0.53      0.52      0.52    530166
# weighted avg       0.53      0.52      0.52    530166

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_12                │ (None, 3, 512)         │       583,680 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 3, 512)         │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_13                │ (None, 3, 256)         │       656,384 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 3, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_14                │ (None, 128)            │       164,352 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,425,804 (5.44 MB)
#  Trainable params: 1,424,010 (5.43 MB)
#  Non-trainable params: 1,792 (7.00 KB)
#  Optimizer params: 2 (12.00 B)
